# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Reading csv and creating a dataframe
df = pd.read_csv("housing.csv")
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
# converting to 2D array 
dataset = df.values
dataset
# Out:
# array([[6.575e+00, 4.980e+00, 1.530e+01, 5.040e+05],
#        [6.421e+00, 9.140e+00, 1.780e+01, 4.536e+05],
#        [7.185e+00, 4.030e+00, 1.780e+01, 7.287e+05],
#        ...,
#        [6.976e+00, 5.640e+00, 2.100e+01, 5.019e+05],
#        [6.794e+00, 6.480e+00, 2.100e+01, 4.620e+05],
#        [6.030e+00, 7.880e+00, 2.100e+01, 2.499e+05]])

# %%
# Sperate train and test data
X = dataset[:, 0:3]
y = dataset[:, 3]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
# There are three steps to model something with sklearn
# 1. Set up the model
model = LinearRegression()
# 2. Use fit
model.fit(X_train, Y_train)
# 3. Check the score
model.score(X_validation, Y_validation)
# Out:
# 0.7042069943455358

# %%
# You can also get the coefficients
model.coef_
# Out:
# array([ 78887.35875343, -10981.11109003, -20395.34978704])

# %%
# Predict unkown data
model.predict(X_validation)
# Out:
# array([304643.42627625, 390061.33246735, 568624.20252355, 765557.90436091,
#        476516.81993921, 564492.39618682, 382097.56449001, 578244.82649948,
#        316944.3450546 , 511598.93238982, 476985.93514109, 561707.71324984,
#        427561.57384348, 590571.45027625, 118870.13549162, 364321.36636403,
#        529712.08108131, 474064.34401908, 620299.80385274, 574545.50690914,
#        463070.05096149, 395213.15940174, 327466.51947627, 619337.769821  ,
#        731855.43603246, 393649.04017524, 377113.11805416, 369894.01146681,
#        319608.50923341, 436200.31926417, 670038.19856565, 642412.54514822,
#        648608.17623859, 611590.74107599, 574887.1584512 , 584355.80489746,
#        562016.0273764 , 576507.18157435, 710811.53294615, 493795.01881365,
#        405324.50455132, 391874.27479534, 399048.89031224, 503414.58716557,
#        191000.89138483, 435884.03036321, 521310.67086429, 532228.67437943,
#        556346.23818058, 539496.85517271, 486543.26781051, 405532.75145607,
#        424799.53223528, 626727.12830915, 370845.18490721, 425741.50005475,
#        397685.04301877, 536288.15858992, 732709.55156402, 465992.26370839,
#        351313.01049816, 604259.71739001, 740034.72373216, 145855.84317492,
#        357974.42518978, 360555.0267579 , 382828.99504006, 252220.42805405,
#        546426.70773945, 454343.32712673, 513025.21130331, 383335.12727035,
#        363890.96553573, 682514.29434293, 562919.50208972, 449986.6625723 ,
#        631818.14351759, 505036.20700836, 518359.47061472, 492042.17494491,
#        534144.51740101, 528579.28912949, 406019.35837238, 367853.05538568,
#        407395.08395071, 432998.77726325, 393539.35278435, 686543.24603096,
#        270583.72821434, 515471.42440626, 314595.2792935 , 506010.62901438,
#        547787.55378106, 535096.28366355, 357887.36471299, 427318.45606402,
#        528243.24169189, 321925.49174402])

# %%
Y_pred = model.predict(X_validation)
plt.plot(Y_validation, Y_pred, '.')
# plot a line, a perfit predict would all fall on this line
x = np.linspace(0, 990000, 100)
y = x
plt.plot(x, y)
plt.xlabel("Actual value")
plt.ylabel("predicted value")
plt.show()

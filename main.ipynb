# %%
#all imports
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sb
from pandas_datareader import data as pdr

# %%
# yfinance dataframe
yf.pdr_override() 

#set company ticker symbol
company = "AAPL"

# download dataframe
data = pdr.get_data_yahoo(company, start="2010-01-01", end="2020-09-10")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# dataframe for model
prices = data[data.columns[0:1]]
prices.reset_index(level=0,inplace = True)
prices
# Out:
#            Date        Open
# 0    2009-12-31    7.611786
# 1    2010-01-04    7.622500
# 2    2010-01-05    7.664286
# 3    2010-01-06    7.656428
# 4    2010-01-07    7.562500
# ...         ...         ...
# 2686 2020-09-02  137.589996
# 2687 2020-09-03  126.910004
# 2688 2020-09-04  120.070000
# 2689 2020-09-08  113.949997
# 2690 2020-09-09  117.260002
#
# [2691 rows x 2 columns]

# %%
#visualize dataframe
sb.lineplot(x="Date", y="Open", data=price,)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>
